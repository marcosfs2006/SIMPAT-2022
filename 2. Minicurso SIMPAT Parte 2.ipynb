# %% [markdown]
# <center>
#
# ![](https://drive.google.com/uc?export=view&id=1PgkZoONy_X0nTFpReHVrWa58NVlxZtd4)
#
# </center>

# %% [markdown]
# # <center> <font color="blue" size=6> **Minicurso: R e Google Colab Aplicados à Análise de Dados Atuariais <br><br> Parte 2 - Usando o Colab**</font><center>
#
# Instrutor: [Marcos F. Silva](https://audinalytics.netlify.app/)
# Repositório do Minicurso no GitHub: https://github.com/marcosfs2006/SIMPAT-2022

# %% [markdown]
# # **Objetivo da Parte 2**
#
# Nesta parte do minicurso, após termos nos familiarizado com o ambiente Google Colab vamos efetivamente utilizá-lo.
#
# Para ilustrar sua utilização, vamos extrair dados da API do CADPREV (<https://apicadprev.economia.gov.br/api-docs/>), e realizar algumas análises nos dados obtidos.
#
# Vamos examinar alguns notebooks que ilustram como os notebooks podem ser utilizados para análise de dados no ambiente profissional.
#
# Vamos examinar os seguintes notebooks:
#
# * [DRAA Plano de Beneficios.ipynb](https://colab.research.google.com/drive/1NJo7CvlMhlKRbkjCYTJsacSQVidwzkmv?usp=sharing)
# * [Testes de Razoabilidade de Fluxo Atuarial.ipynb](https://colab.research.google.com/drive/1C_ZK9Z7Ri52sQgApkoWUxrk_GDHFysOJ?usp=sharing)
# * [Extrai Dados do DRAA.ipynb](https://colab.research.google.com/drive/1fZFyjNeJu6A3HE0goBRTBmtyqvqNyFGh?usp=sharing)
