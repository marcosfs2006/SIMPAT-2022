# %% [markdown]
# <!--
#
# <img src="https://drive.google.com/uc?export=view&id=1ytfR4Tnfh6q1E0zEV4D3X-MJTlR7sNBm" width="500" height="250">
#
# ![](https://drive.google.com/uc?export=view&id=1xWsAffoRjZLoZcbzoG10sFrkmSwAMJgv)
#
#
# https://drive.google.com/file/d/1Z5uZ7D68EFZL3417RYe3DrPpg4OQePGZ/view?usp=sharing
# -->
# <br><br>
#
# <center>
#
# <img src="https://drive.google.com/uc?export=view&id=1Z5uZ7D68EFZL3417RYe3DrPpg4OQePGZ" width="500" height="250">
#
# </center>

# %% [markdown]
# # <center> <font color="blue" size=6> **Minicurso: R e Google Colab Aplicados à Análise de Dados Atuariais**</font><center>
#
# Instrutor: [Marcos F. Silva](https://audinalytics.netlify.app/)
# Repositório do Minicurso no GitHub: https://github.com/marcosfs2006/SIMPAT-2022

# %% [markdown]
# # **PROGRAMA**
#
# <br>

# %% [markdown]
# # **[Parte 1 - O Ambiente Colab](https://colab.research.google.com/drive/1jeFj7pazazTNMezJovluCi9GPxw2VRzv?usp=sharing)**
# ---
#
# * Vantagens e desvantagens do Colab;
# * Criar um notebook no Colab rodando R;
# * Criar células de fórmulas e de texto;
# * Editar o documento (inserir títulos, figuras, links, equações, etc);
# * Executar as células de código;
# * Evitar mensagens indesejadas no carregamento e instalação de pacotes;
# * Movimentar as células do notebook;
# * Adicionar formulários ao notebook para captar dados;
# * Subir arquivos de dados para análise no Colab;
# * Salvar notebooks no computador, no Google Drive ou no GitHub;
# * Importar dados armazenados no GitHub ou no GoogleDrive

# %% [markdown]
# # **[Parte 2 - Criando um Extrator de Dados Previdenciários](https://colab.research.google.com/drive/1Yb88rk7Fm_0nxh6AuG6zE_vkiD0SFdkC?usp=sharing)**
# ---
#
# * Extrair dados do DRAA da API da SPREV e realizar análise (a ideia é construir um notebook para puxar os dados do DRAA na API da SPREV e realizar algumas análises)
