# %% [markdown]
# # Parte I - Formatando o Colab
#
# 1\. Crie um novo notebook. Nomeie de "SIMPAT 2022 - Exercícios.ipynb"
#
# <br>
#
# 2\. Crie uma célula de texto e inclua o seguinte título de nível 3: "Lista de exercícios. Parte I". Coloque o título em negrito.
#
# <br>
#
# 3\. Escreva abaixo do título criado a seguinte frase: "O ambiente Colab é muito interessante para o desenvolvimento de trabalho de forma colaborativa."
# Ponha a palavra "Colab" em negrito e em itálico.  Sublinhe a palavra "colaborativa".
#
# <br>
#
# 4\. Insira uma tabela com o conteúdo abaixo e a centralize:
#
# ![](https://drive.google.com/uc?export=view&id=1CtFwKAQg8MuwHYm1udutBnELBT7t52Rn)
#
# <br>
#
# 5\. Escreva a fórmula V =  1/3 * pi * r ^ 2 * h
#
# <br>
#
# 6\. O link abaixo é de uma figura que está no Google Drive. Crie uma nova célula e insira a figura a que se refere esse link.
#
# https://drive.google.com/file/d/15h_wSh-2XQrkgRr-jtEP_lOtBBz1kgRt/view?usp=sharing
#
# <br>
#
# 7\. Crie uma lista igual a mostrada a seguir:
#
# ![](https://drive.google.com/uc?export=view&id=1l6UXk_nVRooioitBLL5dlmSIniCLJY5T)
#
# <br>
#
# 8\. Insira um link na palavra "SIMPAT" de forma que o usuário seja direcionado para a página do simpósio. `https://simpatufs.wixsite.com/xisimpat`
#
# <br>
#
# 9\. Crie uma célula de código e execute o seguinte comando:
#
# `plot(mpg ~ wt, data=mtcars, pch=16, col="blue")`
#
# <br>

# %% [markdown]
# # Parte II - Operando o Colab
#
# 10\. Vá no reposítório do minicurso no GitHub (`https://github.com/marcosfs2006/SIMPAT-2022`) baixe o arquivo `2019_FLX_CIVIL_PREV_GA_XXXXXXXXXXXXXX.csv` e faça o upload para o netebook.
#
# <br>
#
# 11\. Crie uma célula de código cntendo um formuário que colete a altura (em metros) e o peso (em kilos) e que, após ser executada, retorne o valor do índicd de massa corporal (IMC) que é expresso pela fórmula: `IMC = peso / altura ^ 2`
#
# <br>
#
# 12\. Crie duas novas células abaixo da célula anterior e coloque as questões 8 e 9 em cada uma das novas céluas criadas.
